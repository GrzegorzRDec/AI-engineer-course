# %% [markdown]
# Modules 3,4,5 in self learning
#
#
# Feature scaling concept

# %%
import pandas as pd
import os

os.getcwd()
os.chdir("D:\\Kurs AI Engineer\\BreastCancerDataset")
os.getcwd()
file = "data.csv"
dataset = pd.read_csv(file)
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# # Pandas
#
# dataframe: csv

# %%
dataset.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ogarnąć funkcje fillna (wypełnia NaN podają jako argument wartością)
# mean etc:
#
# dataFrame.dropna() - drops entires rows if finds NaN value

# %%
dataset.skew()
# Out:
# id                         6.473752
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               5.110463
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# ...

# %%
dataset.sort_values('radius_mean',ascending=True)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 101     862722         B        6.981         13.43           43.79
# 539     921362         B        7.691         25.44           48.34
# 538     921092         B        7.729         25.49           47.98
# 568      92751         B        7.760         24.54           47.92
# 46    85713702         B        8.196         16.84           51.71
# ..         ...       ...          ...           ...             ...
# 82     8611555         M       25.220         24.91          171.50
# 352     899987         M       25.730         17.46          174.20
# 180     873592         M       27.220         21.87          182.10
# 461  911296202         M       27.420         26.27          186.90
# 212    8810703         M       28.110         18.47          188.50
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 101      143.5          0.11700           0.07568         0.00000
# ...

# %%
dataset.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df = pd.DataFrame({'Club':['Siarka','Arsenal','Siarka','Wisła','Arsenal','Siarka'],
                   'Player':['Kukiełka','Dupa','Krych','Majdan','Kretyn','Siup'],
                   'Goals':[1,2,3,4,5,6]})
df
# Out:
#       Club    Player  Goals
# 0   Siarka  Kukiełka      1
# 1  Arsenal      Dupa      2
# 2   Siarka     Krych      3
# 3    Wisła    Majdan      4
# 4  Arsenal    Kretyn      5
# 5   Siarka      Siup      6

# %%
df['Club']
# Out:
# 0     Siarka
# 1    Arsenal
# 2     Siarka
# 3      Wisła
# 4    Arsenal
# 5     Siarka
# Name: Club, dtype: object

# %%
rtn = df['Goals'].groupby(df['Club'])

# %%
rtn.sum()
# Out:
# Club
# Arsenal     7
# Siarka     10
# Wisła       4
# Name: Goals, dtype: int64

# %%
rtn.mean()
# Out:
# Club
# Arsenal    3.500000
# Siarka     3.333333
# Wisła      4.000000
# Name: Goals, dtype: float64
